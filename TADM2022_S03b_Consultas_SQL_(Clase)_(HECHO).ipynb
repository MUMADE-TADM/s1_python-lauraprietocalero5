# %% [markdown]
# <a href="https://colab.research.google.com/github/MUMADE-TADM/s1_python-lauraprietocalero5/blob/main/TADM2022_S03b_Consultas_SQL_(Clase)_(HECHO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laura Prieto Calero

# %% [markdown]
# # Consultas SQL

# %% [markdown]
# Antes de empezar cargamos nuestro archivo data_berka en nuestro entorno: [enlace](https://sorry.vse.cz/~berka/challenge/pkdd1999/berka.htm)

# %%
# !gdown --id 1Osmr7qVN0NMuqYxvLesNn7H4nqPCVbsU
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1Osmr7qVN0NMuqYxvLesNn7H4nqPCVbsU
# To: /content/data_berka.db
# 100% 70.2M/70.2M [00:00<00:00, 227MB/s]

# %% [markdown]
# En primer lugar cargamos la extensión que nos va permitir manejar comandos sql directamente en colab

# %%
# %load_ext sql

# %% [markdown]
# Y conectamos con la base de datos

# %%
# %sql sqlite:///data_berka.db
# Out:
# 'Connected: @data_berka.db'

# %% [markdown]
# Comprobamos esquema

# %%
# %%sql
# SELECT name,type
# FROM sqlite_master
# WHERE type = 'table'
# Out:
#  * sqlite:///data_berka.db
# Done.
# [('DISTRICT', 'table'),
#  ('ACCOUNT', 'table'),
#  ('TRANS', 'table'),
#  ('CLIENT', 'table'),
#  ('DISPOSITION', 'table'),
#  ('CREDIT_CARD', 'table'),
#  ('LOAN', 'table'),
#  ('PERMANENT_ORDER', 'table')]

# %% [markdown]
# ## Consultas sobre Préstamos

# %% [markdown]
# 1. Obtener todos los atributos que tiene el banco sobre sus préstamos.
#
# (extra limitar a 20 registros)

# %% [markdown]
# Con el siguiente código vamos a pedir que seleccione todas las columnas de la variable LOAN, extralimitando a 20 registros con el código LIMIT

# %%
# %%sql
# SELECT*
# FROM LOAN
# LIMIT 20
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(5314, 1787, 930705, 96396, 12, 8033, 'B'),
#  (5316, 1801, 930711, 165960, 36, 4610, 'A'),
#  (6863, 9188, 930728, 127080, 60, 2118, 'A'),
#  (5325, 1843, 930803, 105804, 36, 2939, 'A'),
#  (7240, 11013, 930906, 274740, 60, 4579, 'A'),
#  (6687, 8261, 930913, 87840, 24, 3660, 'A'),
#  (7284, 11265, 930915, 52788, 12, 4399, 'A'),
#  (6111, 5428, 930924, 174744, 24, 7281, 'B'),
#  (7235, 10973, 931013, 154416, 48, 3217, 'A'),
#  (5997, 4894, 931104, 117024, 24, 4876, 'A'),
#  (7121, 10364, 931110, 21924, 36, 609, 'A'),
#  (6077, 5270, 931122, 79608, 24, 3317, 'A'),
#  (6228, 6034, 931201, 464520, 60, 7742, 'B'),
#  (6356, 6701, 931208, 95400, 36, 2650, 'A'),
#  (5523, 2705, 931208, 93888, 36, 2608, 'A'),
#  (6456, 7123, 931209, 47016, 12, 3918, 'A'),
#  (7104, 10320, 931213, 259740, 60, 4329, 'A'),
#  (6820, 9034, 931216, 38148, 12, 3179, 'A'),
#  (6876, 9236, 931221, 86616, 12, 7218, 'A'),
#  (7097, 10266, 931223, 75624, 24, 3151, 'B')]

# %% [markdown]
# 2. Obtener los campos de fecha (date), amount (cantidad), duración (duration), pagos (payments), estado (status)
#
# (extra limitar a 20 registros)

# %% [markdown]
# Con el siguiente código estamos selecionando las columnas indicadas en el enunciado de la variable LOAn (con la función FROM) y lo estamos ordenando según "amount" en orden descendente (DESC). Del mismo modo, lo estamos extralimitando a 20 registros con la función LIMIT.

# %%
# %%sql
# SELECT date, amount, duration, payments, status
# FROM LOAN
# ORDER BY amount DESC
# LIMIT 20
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(971019, 590820, 60, 9847, 'C'),
#  (980123, 566640, 60, 9444, 'C'),
#  (971112, 541200, 60, 9020, 'D'),
#  (950217, 538500, 60, 8975, 'C'),
#  (980120, 504000, 60, 8400, 'C'),
#  (980522, 495180, 60, 8253, 'C'),
#  (941219, 482940, 60, 8049, 'D'),
#  (970212, 475680, 48, 9910, 'C'),
#  (970907, 473280, 60, 7888, 'D'),
#  (971225, 468060, 60, 7801, 'C'),
#  (970613, 466608, 48, 9721, 'C'),
#  (971227, 465504, 48, 9698, 'D'),
#  (950709, 465072, 48, 9689, 'C'),
#  (931201, 464520, 60, 7742, 'B'),
#  (971105, 460980, 60, 7683, 'D'),
#  (960723, 444864, 48, 9268, 'C'),
#  (980829, 437460, 60, 7291, 'C'),
#  (980213, 428784, 48, 8933, 'C'),
#  (961118, 421008, 48, 8771, 'C'),
#  (951029, 419880, 60, 6998, 'C')]

# %% [markdown]
# 3. Obtener los distintos tipos de estado que se presentan en un préstamo.

# %% [markdown]
# El siguiente código está indicando que se seleccionen los distintos "status" con la función SELECT DISTINCT de LOAN y que lo ordene

# %%
# %%sql
# SELECT DISTINCT status
# FROM LOAN
# ORDER BY status
# Out:
#  * sqlite:///data_berka.db
# Done.
# [('A',), ('B',), ('C',), ('D',)]

# %% [markdown]
# 4. Obtener solo los prestamos ya terminados y Ordenar lo anterior por duración y cantidad

# %% [markdown]
# En este caso, la diferencia con los códigos explicados en los casos anteriores, es la función WHERE, con la que estamos indicando que nos muestre únicamentre los casos cuyos estados sea A y B (préstamos ya terminados)

# %%
# %%sql
# SELECT *
# FROM LOAN
# WHERE status in("A", "B")
# ORDER BY duration, amount DESC
# LIMIT 100
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(6934, 9494, 970209, 116832, 12, 9736, 'A'),
#  (5002, 173, 940531, 104808, 12, 8734, 'A'),
#  (4986, 97, 970810, 102876, 12, 8573, 'A'),
#  (5375, 2106, 961003, 101520, 12, 8460, 'A'),
#  (7253, 11079, 970426, 98304, 12, 8192, 'A'),
#  (6998, 9833, 940521, 97632, 12, 8136, 'A'),
#  (6612, 7907, 970831, 97392, 12, 8116, 'A'),
#  (5314, 1787, 930705, 96396, 12, 8033, 'B'),
#  (6995, 9814, 960926, 96168, 12, 8014, 'A'),
#  (5464, 2419, 950130, 95808, 12, 7984, 'A'),
#  (5643, 3273, 970921, 94512, 12, 7876, 'B'),
#  (5377, 2116, 970804, 92400, 12, 7700, 'A'),
#  (5519, 2694, 940308, 91632, 12, 7636, 'A'),
#  (7046, 10049, 970328, 91632, 12, 7636, 'A'),
#  (5868, 4361, 970329, 90156, 12, 7513, 'A'),
#  (7277, 11231, 971024, 89280, 12, 7440, 'A'),
#  (4996, 132, 961106, 88440, 12, 7370, 'A'),
#  (5882, 4427, 940926, 87816, 12, 7318, 'A'),
#  (7119, 10361, 970602, 86880, 12, 7240, 'A'),
#  (6876, 9236, 931221, 86616, 12, 7218, 'A'),
#  (6921, 9422, 961029, 86184, 12, 7182, 'A'),
#  (5366, 2062, 961029, 86184, 12, 7182, 'A'),
#  (6150, 5622, 941102, 83016, 12, 6918, 'A'),
#  (5595, 3050, 940902, 82896, 12, 6908, 'A'),
#  (6678, 8173, 940520, 80340, 12, 6695, 'A'),
#  (6059, 5196, 971228, 79824, 12, 6652, 'A'),
#  (5285, 1603, 940206, 78936, 12, 6578, 'A'),
#  (7051, 10068, 970728, 77808, 12, 6484, 'A'),
#  (6642, 8027, 940605, 77640, 12, 6470, 'A'),
#  (5117, 718, 970820, 76944, 12, 6412, 'A'),
#  (6316, 6473, 940526, 76908, 12, 6409, 'B'),
#  (5739, 3747, 950102, 76380, 12, 6365, 'A'),
#  (5992, 4863, 970318, 76080, 12, 6340, 'A'),
#  (6729, 8519, 940811, 74688, 12, 6224, 'A'),
#  (5878, 4415, 970401, 74040, 12, 6170, 'A'),
#  (6599, 7859, 961119, 72120, 12, 6010, 'A'),
#  (6624, 7965, 940930, 71460, 12, 5955, 'A'),
#  (5352, 1993, 950415, 68400, 12, 5700, 'B'),
#  (5638, 3249, 970827, 68124, 12, 5677, 'A'),
#  (6598, 7857, 950118, 68112, 12, 5676, 'A'),
#  (6753, 8688, 970320, 67980, 12, 5665, 'A'),
#  (5682, 3455, 970307, 67464, 12, 5622, 'A'),
#  (7201, 10807, 970307, 67464, 12, 5622, 'A'),
#  (6202, 5891, 940418, 65184, 12, 5432, 'A'),
#  (5750, 3804, 960208, 63252, 12, 5271, 'A'),
#  (5388, 2153, 961128, 61560, 12, 5130, 'A'),
#  (5338, 1888, 970830, 57360, 12, 4780, 'B'),
#  (7305, 11359, 960806, 54024, 12, 4502, 'A'),
#  (5398, 2187, 971104, 53472, 12, 4456, 'A'),
#  (5134, 825, 970202, 53076, 12, 4423, 'A'),
#  (7284, 11265, 930915, 52788, 12, 4399, 'A'),
#  (5856, 4320, 970809, 51360, 12, 4280, 'B'),
#  (6650, 8073, 940217, 49320, 12, 4110, 'B'),
#  (6456, 7123, 931209, 47016, 12, 3918, 'A'),
#  (7198, 10788, 940823, 45768, 12, 3814, 'A'),
#  (7199, 10789, 971209, 45768, 12, 3814, 'A'),
#  (7264, 11141, 971007, 44940, 12, 3745, 'A'),
#  (6137, 5574, 960410, 44628, 12, 3719, 'A'),
#  (6144, 5593, 960809, 44376, 12, 3698, 'A'),
#  (6315, 6472, 950206, 43164, 12, 3597, 'A'),
#  (6621, 7957, 970614, 42900, 12, 3575, 'A'),
#  (6727, 8505, 971210, 42840, 12, 3570, 'A'),
#  (6535, 7546, 951102, 41952, 12, 3496, 'A'),
#  (6895, 9307, 940919, 41904, 12, 3492, 'A'),
#  (6888, 9265, 940711, 39576, 12, 3298, 'A'),
#  (6887, 9263, 970508, 39576, 12, 3298, 'A'),
#  (5634, 3229, 970501, 39024, 12, 3252, 'A'),
#  (5358, 2018, 970121, 38520, 12, 3210, 'A'),
#  (6820, 9034, 931216, 38148, 12, 3179, 'A'),
#  (6362, 6738, 951031, 37908, 12, 3159, 'A'),
#  (6306, 6425, 941220, 36684, 12, 3057, 'A'),
#  (6929, 9472, 950508, 36396, 12, 3033, 'A'),
#  (7008, 9897, 950922, 36168, 12, 3014, 'A'),
#  (6310, 6440, 970617, 34572, 12, 2881, 'A'),
#  (5932, 4626, 970618, 33348, 12, 2779, 'A'),
#  (6758, 8742, 970729, 33144, 12, 2762, 'A'),
#  (5576, 2962, 941221, 31248, 12, 2604, 'A'),
#  (6501, 7418, 960429, 30276, 12, 2523, 'B'),
#  (4961, 19, 960429, 30276, 12, 2523, 'B'),
#  (6502, 7424, 971208, 30276, 12, 2523, 'A'),
#  (4962, 25, 971208, 30276, 12, 2523, 'A'),
#  (6865, 9199, 960911, 29448, 12, 2454, 'B'),
#  (6578, 7765, 951211, 27984, 12, 2332, 'A'),
#  (5005, 176, 970410, 27456, 12, 2288, 'A'),
#  (5479, 2486, 940110, 24516, 12, 2043, 'A'),
#  (5130, 813, 940511, 24312, 12, 2026, 'A'),
#  (5723, 3674, 940910, 23628, 12, 1969, 'A'),
#  (5229, 1329, 970906, 23520, 12, 1960, 'A'),
#  (6878, 9242, 970124, 23184, 12, 1932, 'A'),
#  (5754, 3834, 940928, 23052, 12, 1921, 'A'),
#  (5980, 4825, 950818, 21396, 12, 1783, 'A'),
#  (5922, 4580, 950805, 20220, 12, 1685, 'A'),
#  (5651, 3329, 971208, 19248, 12, 1604, 'A'),
#  (5740, 3752, 950402, 18564, 12, 1547, 'A'),
#  (6942, 9513, 970716, 18324, 12, 1527, 'A'),
#  (6297, 6363, 941025, 17508, 12, 1459, 'A'),
#  (6377, 6792, 970317, 17184, 12, 1432, 'A'),
#  (5599, 3064, 950321, 15420, 12, 1285, 'A'),
#  (6064, 5215, 940804, 14628, 12, 1219, 'A'),
#  (5718, 3637, 970901, 14028, 12, 1169, 'A')]

# %% [markdown]
# Cargar el resultado de la sql en un DataFrame de Pandas

# %% [markdown]
# El primer paso es importar la librería *pandas* y ejecutar sql, incluyendo lo calculado en el paso anterior en el data.frame.
# Una vez tengamos el data frame lo transformamos

# %%
# Importar librería
import pandas as pd
# Ejecutar sql
df = %sql SELECT * FROM LOAN WHERE status in ("A", "B") ORDER BY duration, amount DESC
# Transformar en DataFrame de pandas
df.DataFrame().to_csv("first_sql.csv")
# Out:
#  * sqlite:///data_berka.db
# Done.

# %% [markdown]
#  Ex. 2
#
# > Seleccionar fecha, cantidad, duración y pagos de aquellos préstamos que han sido terminados con una duración mayor de 12 meses ordenados de mayor a menos cantidad de dinero.
#
# >extra: volcar en un DataFrame

# %% [markdown]
# Indicamos con SELECT las columnas que nos indica el enunciado, de LOAN (con FROM) y con WHERE le indicamos las condiciones indicadas.
# Con ORDER BY lo ordenamos según "amount" en orden descendente.

# %%
# %%sql
# SELECT date, amount, duration, payments
# FROM LOAN
# WHERE status in ("A", "B") AND duration>12
# ORDER BY amount DESC
# Out:
#  * sqlite:///data_berka.db
# Done.
# [
#  (940105, 80952, 24, 3373),
#  (940105, 80952, 24, 3373),
#  (940827, 79632, 24, 3318),
#  (931122, 79608, 24, 3317),
#  (950311, 76680, 24, 3195),
#  (950111, 76416, 24, 3184),
#  (931223, 75624, 24, 3151),
#  (940730, 74736, 36, 2076),
#  (951031, 73836, 36, 2051),
#  (960212, 72408, 24, 3017),
#  (950529, 71064, 36, 1974),
#  (940612, 69360, 48, 1445),
#  (961103, 68544, 24, 2856),
#  (960514, 66480, 24, 2770),
#  (940526, 63312, 48, 1319),
#  (960210, 61656, 24, 2569),
#  (941103, 61056, 48, 1272),
#  (951112, 60156, 36, 1671),
#  (941104, 59760, 24, 2490),
#  (940315, 55368, 24, 2307),
#  (940604, 52128, 24, 2172),
#  (940311, 51696, 24, 2154),
#  (941208, 51408, 24, 2142),
#  (941106, 48672, 36, 1352),
#  (950108, 48624, 24, 2026),
#  (950410, 47304, 24, 1971),
#  (960629, 46320, 24, 1930),
#  (950829, 45336, 24, 1889),
#  (950801, 44088, 24, 1837),
#  (950327, 31728, 24, 1322),
#  (951128, 31176, 24, 1299),
#  (950613, 29784, 24, 1241),
#  (950304, 28248, 24, 1177),
#  (940526, 25944, 24, 1081),
#  (931110, 21924, 36, 609),
#  (951008, 21852, 36, 607),
#  (940121, 21072, 24, 878),
#  (960925, 15192, 24, 633),
#  (941002, 11736, 24, 489),
#  (940330, 7656, 24, 319)]

# %% [markdown]
# ¿Cuántos registros cumplen esa condición?

# %% [markdown]
# Le pedimos con *count* que nos cuente los registros que existen con las condiciones indicadas con *WHERE*

# %%
# %%sql
# SELECT count(*)
# FROM LOAN
# WHERE status in ("A", "B") AND duration>12
# ORDER BY amount DESC
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(131,)]

# %% [markdown]
# ¿Cuántos préstamos hay en ejecución (running) con duración entre 24 y 48 meses?

# %% [markdown]
# *count* para contar los datos con las condicones indicadas en *WHERE*

# %%
# %%sql
# SELECT count(*)
# FROM LOAN
# WHERE status in ("C", "D") and duration between 24 and 48
# ORDER BY amount DESC
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(279,)]

# %% [markdown]
# ## Group By

# %% [markdown]
# 7. ¿Cuántos préstamos hay por cada estado y cual es la media de la cantidad de dinero prestado y cual es la media de la cantidad de dinero prestado?

# %% [markdown]
# - WHERE: SE FILTRAN LOS REGISTROS ANTES DE AGRUPARLOS
# - HAVING: SE FILTRAN LOS GRUPOS TRAS OBTENERLOS

# %%
# %%sql
# SELECT status, count(*) as total, avg (amount)
# FROM LOAN
# WHERE duration >=24
# GROUP BY status
# HAVING total > 25
# ORDER BY total DESC
# Out:
#  * sqlite:///data_berka.db
# Done.
# [('C', 376, 180343.1489361702),
#  ('A', 110, 122425.2),
#  ('D', 44, 254127.27272727274)]

# %% [markdown]
# 8. Por cada Región, quiero contar el número de ciudades y obtener el total del número de habitantes de la región.
#
# EXTRA: no considerar la región de Praga

# %%
# %%sql
# SELECT * FROM DISTRICT
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(1, 'Hl.m. Praha', 'Prague', 1204953, 0, 0, 0, 1, 1, 100.0, 12541, 0.29, 0.43, 167, 85677, 99107),
#  (2, 'Benesov', 'central Bohemia', 88884, 80, 26, 6, 2, 5, 46.7, 8507, 1.67, 1.85, 132, 2159, 2674),
#  (3, 'Beroun', 'central Bohemia', 75232, 55, 26, 4, 1, 5, 41.7, 8980, 1.95, 2.21, 111, 2824, 2813),
#  (4, 'Kladno', 'central Bohemia', 149893, 63, 29, 6, 2, 6, 67.4, 9753, 4.64, 5.05, 109, 5244, 5892),
#  (5, 'Kolin', 'central Bohemia', 95616, 65, 30, 4, 1, 6, 51.4, 9307, 3.85, 4.43, 118, 2616, 3040),
#  (6, 'Kutna Hora', 'central Bohemia', 77963, 60, 23, 4, 2, 4, 51.5, 8546, 2.95, 4.02, 126, 2640, 3120),
#  (7, 'Melnik', 'central Bohemia', 94725, 38, 28, 1, 3, 6, 63.4, 9920, 2.26, 2.87, 130, 4289, 4846),
#  (8, 'Mlada Boleslav', 'central Bohemia', 112065, 95, 19, 7, 1, 8, 69.4, 11277, 1.25, 1.44, 127, 5179, 4987),
#  (9, 'Nymburk', 'central Bohemia', 81344, 61, 23, 4, 2, 6, 55.3, 8899, 3.39, 3.97, 149, 2987, 2487),
#  (10, 'Praha - vychod', 'central Bohemia', 92084, 55, 29, 4, 3, 5, 46.7, 10124, 0.56, 0.54, 141, 3810, 4316),
#  (11, 'Praha - zapad', 'central Bohemia', 75637, 35, 36, 9, 0, 7, 36.5, 9622, 0.45, 0.59, 154, 3475, 3529),
#  (12, 'Pribram', 'central Bohemia', 107870, 84, 29, 6, 1, 6, 58.0, 8754, 3.83, 4.31, 137, 3804, 3868),
#  (13, 'Rakovnik', 'central Bohemia', 53921, 61, 22, 1, 1, 2, 41.3, 8598, 2.77, 3.26, 123, 1597, 1875),
#  (14, 'Ceske Budejovice', 'south Bohemia', 177686, 69, 27, 10, 1, 9, 74.8, 10045, 1.42, 1.71, 135, 6604, 6295),
#  (15, 'Cesky Krumlov', 'south Bohemia', 58796, 22, 16, 7, 1, 5, 51.9, 9045, 3.13, 3.6, 124, 1845, 1879),
#  (16, 'Jindrichuv Hradec', 'south Bohemia', 93931, 74, 21, 10, 1, 8, 56.9, 8427, 1.12, 1.54, 107, 1874, 1913),
#  (17, 'Pelhrimov', 'south Bohemia', 74062, 99, 15, 4, 2, 7, 61.4, 8114, 2.38, 2.62, 119, 1003, 1181),
#  (18, 'Pisek', 'south Bohemia', 70699, 60, 13, 2, 1, 4, 65.3, 8968, 2.83, 3.35, 131, 1740, 1910),
#  (19, 'Prachatice', 'south Bohemia', 51428, 50, 11, 3, 1, 4, 52.7, 8402, 3.13, 3.98, 120, 999, 1099),
#  (20, 'Strakonice', 'south Bohemia', 70646, 94, 14, 3, 1, 4, 58.4, 8547, 2.65, 3.64, 120, 1563, 1542),
#  (21, 'Tabor', 'south Bohemia', 103347, 87, 16, 7, 1, 7, 67.0, 9104, 1.51, 2.07, 123, 2299, 2354),
#  (22, 'Domazlice', 'west Bohemia', 58400, 65, 16, 4, 1, 6, 52.4, 8620, 1.1, 1.25, 100, 1089, 1117),
#  (23, 'Cheb', 'west Bohemia', 87419, 21, 11, 4, 3, 9, 85.5, 8624, 1.79, 2.66, 102, 2879, 3198),
#  (24, 'Karlovy Vary', 'west Bohemia', 122603, 25, 21, 6, 2, 8, 80.0, 8991, 1.39, 2.01, 128, 5198, 5273),
#  (25, 'Klatovy', 'west Bohemia', 88757, 60, 33, 3, 2, 10, 61.7, 8554, 2.47, 2.68, 113, 1822, 2218),
#  (26, 'Plzen - mesto', 'west Bohemia', 170449, 0, 0, 0, 1, 1, 100.0, 10787, 2.64, 3.09, 131, 6041, 6261),
#  (27, 'Plzen - jih', 'west Bohemia', 67298, 71, 19, 10, 0, 7, 43.8, 8561, 0.65, 1.29, 110, 1029, 1127),
#  (28, 'Plzen - sever', 'west Bohemia', 72541, 66, 26, 10, 0, 8, 36.9, 8594, 1.62, 2.01, 112, 1580, 1525),
#  (29, 'Rokycany', 'west Bohemia', 45714, 52, 10, 5, 1, 6, 55.6, 8843, 2.82, 3.6, 113, 818, 888),
#  (30, 'Sokolov', 'west Bohemia', 94812, 15, 13, 8, 2, 10, 81.8, 9650, 3.38, 3.67, 100, 2985, 2804),
#  (31, 'Tachov', 'west Bohemia', 51313, 34, 12, 3, 1, 4, 59.2, 8930, 3.52, 4.2, 108, 1328, 1452),
#  (32, 'Ceska Lipa', 'north Bohemia', 105058, 32, 19, 7, 2, 10, 81.0, 9272, 2.8, 3.22, 118, 4340, 4505),
#  (33, 'Decin', 'north Bohemia', 133777, 24, 17, 7, 3, 11, 84.7, 8705, 5.75, 7.61, 116, 4650, 4859),
#  (34, 'Chomutov', 'north Bohemia', 125236, 28, 11, 1, 4, 5, 87.7, 9675, 6.43, 7.68, 100, 5323, 5190),
#  (35, 'Jablonec n. Nisou', 'north Bohemia', 88768, 10, 18, 5, 1, 7, 80.5, 8867, 1.02, 1.21, 130, 3384, 3620),
#  (36, 'Liberec', 'north Bohemia', 159617, 29, 19, 8, 1, 9, 85.2, 9198, 3.33, 4.28, 131, 5796, 6132),
#  (37, 'Litomerice', 'north Bohemia', 114006, 71, 26, 6, 2, 9, 62.3, 9065, 4.46, 5.39, 123, 4147, 4166),
#  (38, 'Louny', 'north Bohemia', 85852, 41, 23, 4, 2, 4, 59.8, 8965, 7.08, 8.23, 104, 2653, 2822),
#  (39, 'Most', 'north Bohemia', 119895, 17, 4, 3, 2, 4, 89.9, 10446, 7.34, 9.4, 90, 4947, 4743),
#  (40, 'Teplice', 'north Bohemia', 128118, 9, 16, 6, 3, 8, 85.3, 9317, 6.49, 7.07, 97, 6949, 6872),
#  (41, 'Usti nad Labem', 'north Bohemia', 118650, 8, 8, 5, 1, 3, 85.6, 9832, 3.32, 4.48, 114, 6445, 5471),
#  (42, 'Havlickuv Brod', 'east Bohemia', 95907, 87, 25, 5, 2, 7, 59.1, 8388, 2.41, 2.94, 87, 1658, 1668),
#  (43, 'Hradec Kralove', 'east Bohemia', 161854, 73, 21, 6, 1, 6, 76.3, 9425, 1.72, 2.5, 125, 4085, 3891),
#  (44, 'Chrudim', 'east Bohemia', 105606, 77, 26, 7, 2, 7, 53.0, 8254, 2.79, 3.76, 97, 2166, 2325),
#  (45, 'Jicin', 'east Bohemia', 77917, 85, 19, 6, 1, 5, 53.5, 8390, 2.28, 2.89, 132, 2080, 2122),
#  (46, 'Nachod', 'east Bohemia', 112709, 48, 20, 7, 3, 10, 73.5, 8369, 1.79, 2.31, 117, 2854, 2618),
#  (47, 'Pardubice', 'east Bohemia', 162580, 83, 26, 5, 1, 6, 72.8, 9538, 1.51, 1.81, 111, 6079, 5410),
#  (48, 'Rychnov nad Kneznou', 'east Bohemia', 78955, 50, 24, 8, 1, 9, 59.0, 9060, 1.78, 2.44, 124, 1655, 1717),
#  (49, 'Semily', 'east Bohemia', 75685, 31, 28, 5, 1, 9, 60.8, 8208, 1.89, 2.26, 155, 1660, 2123),
#  (50, 'Svitavy', 'east Bohemia', 102609, 75, 33, 2, 3, 6, 52.0, 8187, 4.83, 5.45, 94, 2123, 2134),
#  (51, 'Trutnov', 'east Bohemia', 121947, 37, 28, 7, 3, 11, 70.5, 8541, 2.51, 2.97, 131, 3496, 3839),
#  (52, 'Usti nad Orlici', 'east Bohemia', 139012, 59, 41, 8, 3, 10, 61.9, 8363, 2.52, 3.49, 108, 2564, 2799),
#  (53, 'Blansko', 'south Moravia', 107911, 88, 33, 6, 2, 7, 50.9, 8240, 2.53, 3.56, 99, 1850, 1903),
#  (54, 'Brno - mesto', 'south Moravia', 387570, 0, 0, 0, 1, 1, 100.0, 9897, 1.6, 1.96, 140, 18721, 18696),
#  (55, 'Brno - venkov', 'south Moravia', 157042, 49, 70, 18, 0, 9, 33.9, 8743, 1.88, 2.43, 111, 3659, 3894),
#  (56, 'Breclav', 'south Moravia', 124605, 11, 42, 14, 1, 8, 46.0, 8772, 4.69, 4.98, 126, 2854, 3158),
#  (57, 'Hodonin', 'south Moravia', 161954, 21, 37, 20, 3, 8, 48.0, 8720, 3.73, 4.5, 116, 3729, 3651),
#  (58, 'Jihlava', 'south Moravia', 109164, 98, 16, 6, 1, 4, 63.6, 8757, 3.38, 3.95, 96, 2212, 2471),
#  (59, 'Kromeriz', 'south Moravia', 108871, 41, 29, 7, 2, 6, 62.1, 8444, 3.24, 3.47, 106, 2595, 2305),
#  (60, 'Prostejov', 'south Moravia', 110643, 49, 41, 4, 1, 4, 51.9, 8441, 3.45, 4.48, 115, 1879, 2252),
#  (61, 'Trebic', 'south Moravia', 117897, 139, 28, 5, 1, 6, 53.8, 8814, 4.76, 5.74, 107, 2112, 2059),
#  (62, 'Uherske Hradiste', 'south Moravia', 145688, 22, 41, 13, 2, 5, 40.7, 8544, 1.29, 1.86, 109, 2719, 2906),
#  (63, 'Vyskov', 'south Moravia', 86513, 38, 36, 5, 1, 5, 50.5, 8288, 3.79, 4.52, 110, 1562, 1460),
#  (64, 'Zlin', 'south Moravia', 197099, 29, 41, 10, 2, 10, 74.7, 9624, 1.6, 2.31, 145, 4484, 4265),
#  (65, 'Znojmo', 'south Moravia', 114200, 101, 41, 4, 1, 4, 43.7, 8403, 5.74, 5.72, 105, 2157, 2718),
#  (66, 'Zdar nad Sazavou', 'south Moravia', 125832, 151, 41, 2, 3, 5, 48.3, 8512, 3.51, 4.12, 102, 2247, 2103),
#  (67, 'Bruntal', 'north Moravia', 106054, 38, 25, 6, 2, 6, 63.1, 8110, 5.77, 6.55, 109, 3244, 3079),
#  (68, 'Frydek - Mistek', 'north Moravia', 228848, 15, 40, 18, 2, 6, 57.2, 9893, 4.09, 4.72, 96, 5623, 5887),
#  (69, 'Jesenik', 'north Moravia', 42821, 4, 13, 5, 1, 3, 48.4, 8173, '?', 7.01, 124, '?', 1358),
#  (70, 'Karvina', 'north Moravia', 285387, 0, 2, 8, 5, 7, 89.9, 10177, 6.63, 7.75, 81, 9878, 10108),
#  (71, 'Novy Jicin', 'north Moravia', 161227, 5, 35, 11, 4, 10, 69.7, 8678, 5.93, 5.57, 102, 4980, 4595),
#  (72, 'Olomouc', 'north Moravia', 226122, 32, 50, 7, 4, 4, 62.6, 8994, 3.8, 4.79, 110, 9672, 9208),
#  (73, 'Opava', 'north Moravia', 182027, 17, 49, 12, 2, 7, 56.4, 8746, 3.33, 3.74, 90, 4355, 4433),
#  (74, 'Ostrava - mesto', 'north Moravia', 323870, 0, 0, 0, 1, 1, 100.0, 10673, 4.75, 5.44, 100, 18782, 18347),
#  (75, 'Prerov', 'north Moravia', 138032, 67, 30, 4, 2, 5, 64.6, 8819, 5.38, 5.66, 99, 4063, 4505),
#  (76, 'Sumperk', 'north Moravia', 127369, 31, 32, 13, 2, 7, 51.2, 8369, 4.73, 5.88, 107, 3736, 2807),
#  (77, 'Vsetin', 'north Moravia', 148545, 8, 35, 12, 3, 4, 53.5, 8909, 4.01, 5.56, 113, 3460, 3590)]

# %%
# %%sql
# SELECT A3, count(A2) no_district, sum(A9) no_cities, sum(A4) total_hab
# FROM DISTRICT
# GROUP BY A3
# HAVING no_district > 1
# Out:
#  * sqlite:///data_berka.db
# Done.
# [('central Bohemia', 12, 66, 1105234),
#  ('east Bohemia', 11, 86, 1234781),
#  ('north Bohemia', 10, 70, 1178977),
#  ('north Moravia', 11, 60, 1970302),
#  ('south Bohemia', 8, 48, 700595),
#  ('south Moravia', 14, 82, 2054989),
#  ('west Bohemia', 10, 69, 859306)]

# %% [markdown]
# 9. Contar ordenes permanentes (domiciliaciones) por banco y tipo de transacción

# %%
# %%sql
# SELECT bank_to, k_symbol, count(*) as c
# FROM PERMANENT_ORDER
# WHERE amount < 400
# GROUP BY bank_to, k_symbol
# ORDER BY bank_to
# Out:
#  * sqlite:///data_berka.db
# Done.
# [('AB', ' ', 18),
#  ('AB', 'POJISTNE', 13),
#  ('AB', 'SIPO', 15),
#  ('CD', ' ', 30),
#  ('CD', 'POJISTNE', 10),
#  ('CD', 'SIPO', 14),
#  ('EF', ' ', 20),
#  ('EF', 'POJISTNE', 20),
#  ('EF', 'SIPO', 6),
#  ('EF', 'UVER', 1),
#  ('GH', ' ', 27),
#  ('GH', 'LEASING', 1),
#  ('GH', 'POJISTNE', 16),
#  ('GH', 'SIPO', 15),
#  ('GH', 'UVER', 1),
#  ('IJ', ' ', 26),
#  ('IJ', 'POJISTNE', 14),
#  ('IJ', 'SIPO', 9),
#  ('KL', ' ', 27),
#  ('KL', 'POJISTNE', 14),
#  ('KL', 'SIPO', 11),
#  ('KL', 'UVER', 1),
#  ('MN', ' ', 20),
#  ('MN', 'POJISTNE', 17),
#  ('MN', 'SIPO', 6),
#  ('MN', 'UVER', 1),
#  ('OP', ' ', 24),
#  ('OP', 'POJISTNE', 21),
#  ('OP', 'SIPO', 6),
#  ('QR', ' ', 17),
#  ('QR', 'POJISTNE', 15),
#  ('QR', 'SIPO', 14),
#  ('ST', ' ', 30),
#  ('ST', 'POJISTNE', 16),
#  ('ST', 'SIPO', 12),
#  ('ST', 'UVER', 2),
#  ('UV', ' ', 25),
#  ('UV', 'POJISTNE', 11),
#  ('UV', 'SIPO', 8),
#  ('WX', ' ', 23),
#  ('WX', 'POJISTNE', 24),
#  ('WX', 'SIPO', 11),
#  ('YZ', ' ', 24),
#  ('YZ', 'POJISTNE', 18),
#  ('YZ', 'SIPO', 9)]

# %% [markdown]
# # JOIN

# %% [markdown]
# 10. ¿Cuántas cuentas de frecuencia mensual tienen un un préstamo activo?

# %% [markdown]
# Con la función SELECT y *count* le pedimos que nos cuente las veces que aparece en la base de datos un préstamo mensual y que aún esté activo. La frecuencia la indicamos con *frecuency* y el estado del préstamo con *status* , concretamente con C y D (préstamos en activo).

# %%
# %%sql
# SELECT count(*) as Cuenta
# FROM  LOAN l, ACCOUNT a
# WHERE l.account_id = a.account_id
# and frequency = "monthly"
# and status in("C","D")
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(369,)]

# %% [markdown]
# 11. Domiciliaciones en cuentas de actualización semanal de alquiler en cuentas de Praga

# %% [markdown]
# Igual que el caso anterior pero cambiamos la frecuencia a semanal y con *and A·* le indicamos que tenga únicamente en cuenta los casos que se den en Praga.

# %%
# %%sql
# SELECT order_id, p.account_id, amount
# FROM PERMANENT_ORDER p, ACCOUNT a, DISTRICT d
# WHERE p.account_id = a.account_id
# and a.district_id = d.A1
# and k_symbol = "LEASING"
# and frequency = "weekly"
# and A3 = "Prague"
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(29514, 72, 2923),
#  (30250, 573, 2249),
#  (30944, 1056, 2531.7),
#  (34056, 3141, 1087),
#  (35237, 3959, 1680.6),
#  (40429, 7465, 1060.6)]

# %% [markdown]
# 12. Domiciliaciones (*órdenes*) semanales para alquiler (*leasing*) en cuentas de Praga
#
#  - Ordenes permanentes de alquiler (*leasing*) y semanales (*weekly*)
#  - Relación con cuentas que tienen región Praga

# %%
# %%sql
# SELECT order_id, k_symbol, bank_to, a.account_id, a.frequency, d.A2, d.A3
# FROM PERMANENT_ORDER p, ACCOUNT a, DISTRICT d
# WHERE p.account_id = a.account_id and a.district_id = d.A1
#     and k_symbol = "LEASING" and a.frequency = "weekly" and d.A3 = "Prague"
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(29514, 'LEASING', 'OP', 72, 'weekly', 'Hl.m. Praha', 'Prague'),
#  (30250, 'LEASING', 'CD', 573, 'weekly', 'Hl.m. Praha', 'Prague'),
#  (30944, 'LEASING', 'IJ', 1056, 'weekly', 'Hl.m. Praha', 'Prague'),
#  (34056, 'LEASING', 'OP', 3141, 'weekly', 'Hl.m. Praha', 'Prague'),
#  (35237, 'LEASING', 'AB', 3959, 'weekly', 'Hl.m. Praha', 'Prague'),
#  (40429, 'LEASING', 'ST', 7465, 'weekly', 'Hl.m. Praha', 'Prague')]

# %% [markdown]
# 13. Transacciones relacionadas con pensiones (DUCHOD) en Plzen desde el banco MN
#
# (limitar a 10)

# %%
# %%sql
# SELECT trans_id, a.account_id, a.frequency, t.type, k_symbol, bank
# FROM TRANS t, ACCOUNT a, DISTRICT d
# WHERE t.account_id = a.account_id and a.district_id = d.A1
#   and k_symbol = "DUCHOD" and bank = "MN" and d.A2 like "Plzen%"
# LIMIT 10
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(47969, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47970, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47971, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47972, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47973, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47974, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47975, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47976, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (47977, 161, 'monthly', 'PRIJEM', 'DUCHOD', 'MN'),
#  (1098524, 3753, 'monthly', 'PRIJEM', 'DUCHOD', 'MN')]

# %% [markdown]
# # Subconsultas

# %% [markdown]
# 14. Prestamos cuya cantidad es superior a la media de los clientes de Praga

# %% [markdown]
# - Cantidad media prestada a los cuentas de Praga

# %% [markdown]
# Lo primero es calcular la media de las cuentas de Praga con *avg (l.amount)*

# %%
# %%sql
# SELECT avg(l.amount)
# FROM LOAN l, ACCOUNT a, DISTRICT D
# WHERE l.account_id = a.account_id and a.district_id = d.A1
# and d.A3 = "Prague"
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(153957.2857142857,)]

# %% [markdown]
# - Consultar los préstamos superiores a esa cantidad

# %% [markdown]
# Indicamos con *WHERE* que nos muestre los casos donde la cantidad (amount) es superior a lo calculado en el paso anterior.
# Además le pedimos que nos lo ordene de mayor a menos cantidad, es decir, de manera descendente.

# %%
# %%sql
# SELECT * FROM LOAN
# WHERE amount > (SELECT avg(l.amount)
#         FROM LOAN l, ACCOUNT a, DISTRICT d
#         WHERE l.account_id = a.account_id and a.district_id = d.A1
#         and d.A3 = "Prague")
# ORDER BY amount DESC
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(6534, 7542, 971019, 590820, 60, 9847, 'C'),
#  (6791, 8926, 980123, 566640, 60, 9444, 'C'),
#  (5447, 2335, 971112, 541200, 60, 9020, 'D'),
#  (5132, 817, 950217, 538500, 60, 8975, 'C'),
#  (5569, 2936, 980120, 504000, 60, 8400, 'C'),
#  (6436, 7049, 980522, 495180, 60, 8253, 'C'),
#  (7142, 10451, 941219, 482940, 60, 8049, 'D'),
#  (6415, 6950, 970212, 475680, 48, 9910, 'C'),
#  (6625, 7966, 970907, 473280, 60, 7888, 'D'),
#  (5043, 339, 971225, 468060, 60, 7801, 'C'),
#  (5486, 2516, 970613, 466608, 48, 9721, 'C'),
#  (5976, 4794, 971227, 465504, 48, 9698, 'D'),
#  (5970, 4774, 950709, 465072, 48, 9689, 'C'),
#  (6228, 6034, 931201, 464520, 60, 7742, 'B'),
#  (5731, 3711, 971105, 460980, 60, 7683, 'D'),
#  (5725, 3679, 960723, 444864, 48, 9268, 'C'),
#  (5561, 2910, 980829, 437460, 60, 7291, 'C'),
#  (5491, 2545, 980213, 428784, 48, 8933, 'C'),
#  (7101, 10297, 961118, 421008, 48, 8771, 'C'),
#  (7304, 11349, 951029, 419880, 60, 6998, 'C'),
#  (7154, 10520, 961205, 417600, 60, 6960, 'C'),
#  (6704, 8377, 950601, 417060, 60, 6951, 'C'),
#  (5419, 2246, 970205, 415800, 60, 6930, 'C'),
#  (6818, 9030, 961212, 155616, 48, 3242, 'C'),
#  (7189, 10728, 960321, 154656, 48, 3222, 'C'),
#  (7235, 10973, 931013, 154416, 48, 3217, 'A')]

# %% [markdown]
# # Repaso de Join/Group By

# %% [markdown]
# ## Objetivo 2.1

# %% [markdown]
# 15 . Clientes de Praga con préstamos según su estado
#
# - ¿Cuántos clientes hay en Praga?
# - ¿Cuántas cuentas tienen asociados clientes en Praga?
# - ¿cuántas de esas cuentas tienen asociados un préstamo?
# - Necesito saber cuántos hay por cada estado (*status*)

# %%
# %%sql
# SELECT status, count(*)
# FROM CLIENT c, DISTRICT d, DISPOSITION dp, LOAN l
# WHERE c.district_id = d.A1 and c.client_id = dp.client_id
# and l.account_id = dp.account_id and d.A3 = "Prague"
# GROUP BY status
# Out:
#  * sqlite:///data_berka.db
# Done.
# [('A', 37), ('B', 3), ('C', 55), ('D', 3)]

# %% [markdown]
# ## Ejercicio
#
# > cantidad de dinero medio en transacciones de clientes propietarios de cuentas en Kolin (owned accounts)

# %%
# %%sql
# SELECT c.client_id, avg (amount) as av
# from client c, district d, disposition ds, account a, trans t
# WHERE c.district_id = d.A1 and c.client_id = ds.client_id
#     and ds.account_id = a.account_id and a.account_id = t.account_id
# and d.A2 = "Kolin" and ds.type = "OWNER"
# GROUP BY c.client_id
# ORDER BY av DESC
# LIMIT 10
# Out:
#  * sqlite:///data_berka.db
# Done.
# [(5249, 15611.831578947369),
#  (3378, 14803.997402597402),
#  (1388, 14464.587096774194),
#  (6803, 13825.125153374232),
#  (8091, 13227.722338204592),
#  (3298, 13074.464857881138),
#  (1806, 13037.759375),
#  (4331, 12644.448051948051),
#  (4974, 12023.291743119267),
#  (3080, 11784.50460251046)]

# %% [markdown]
# > sanction interest if negative balance Cesky Krumlov
#
#
# > stands for loan payment in Praha from the bank EF

# %% [markdown]
# # Extra: Left Join

# %% [markdown]
# 1. ¿Cuántas cuentas hay? 4500
# 2. ¿Cuántas cuentas hay con préstamos? (inner join) 682
# 3. Cuentas con los datos de los préstamos si los hay
# 4. los ordenamos por cantidad

# %%
# %%sql
# SELECT a.account_id, a.date, l.amount, l.status, l.payments, l.duration
# FROM ACCOUNT a INNER OUTER JOIN LOAN l ON a.account_id = l.account_id
# ORDER BY amount DESC
# Out:
#  * sqlite:///data_berka.db
# (sqlite3.OperationalError) unknown or unsupported join type: INNER OUTER
# [SQL: SELECT a.account_id, a.date, l.amount, l.status, l.payments, l.duration
# FROM ACCOUNT a INNER OUTER JOIN LOAN l ON a.account_id = l.account_id
# ORDER BY amount DESC]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# # DataSets
#
# ---

# %% [markdown]
# Dataset sobre las transacciones con Vyskov, extrayendo los años de las diferentes fechas.

# %%
# %%sql dataset << SELECT substr(a.date,0,3) acc_year, substr(t.date, 0, 3) year,amount, balance, k_symbol
# FROM ACCOUNT a, TRANS t, DISTRICT d
# WHERE a.district_id = d.A1 and d.A2 = "Vyskov"
# AND a.account_id = t.account_id
# Out:
#  * sqlite:///data_berka.db
# Done.
# Returning data to local variable dataset

# %%
dataset.DataFrame().to_csv("dataset.csv")
